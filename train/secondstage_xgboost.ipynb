# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import xgboost as xgb
from sklearn.metrics import confusion_matrix    # 生成混淆矩阵函数
import matplotlib.pyplot as plt

# %%
data_dir = "data/"

# %%
test = pd.read_csv(data_dir + "test.csv")
train = pd.read_csv(data_dir + "train.csv")

category_list = train["category"].unique()
category_list.sort()
category_mapping = {label:idx for idx,label in enumerate(category_list)}
num_mapping = {idx:label for idx,label in enumerate(category_list)}

train['category_num'] = train['category'].map(category_mapping)

column_names = []
for i in range(27):
    column_names.append("image_" + str(i))

xgb_column_names = []
for i in range(27):
    xgb_column_names.append("xgb_category_" + str(i))

# train_image_df = pd.read_csv(data_dir + "train_pred_image.csv")
train_image_df2 = pd.read_csv(data_dir + "image2_train_pred.csv")
train_image_df2.columns = column_names

# test_image_df = pd.read_csv(data_dir + "test_pred_image.csv")
test_image_df2 = pd.read_csv(data_dir + "image2_test_pred.csv")
test_image_df2.columns = column_names

dfmin = train_image_df2.min(axis = 1)
dfmax = train_image_df2.max(axis = 1)
train_image_df3 = train_image_df2.copy()
for c in list(train_image_df3.columns):
    train_image_df3.loc[:,c] = (train_image_df2.loc[:,c] - dfmin)/(dfmax-dfmin)

dfmin = test_image_df2.min(axis = 1)
dfmax = test_image_df2.max(axis = 1)
test_image_df3 = test_image_df2.copy()
for c in list(test_image_df3.columns):
    test_image_df3.loc[:,c] = (test_image_df2.loc[:,c] - dfmin)/(dfmax-dfmin)
    
train_fasttext_df = pd.read_csv(data_dir + "train_pred_fast_text.csv")
test_fasttext_df = pd.read_csv(data_dir + "test_pred_fast_text.csv",nrows=21628)

train_lstm_df = pd.read_csv(data_dir + "train_lstm_X.csv")
train_lstm_df = train_lstm_df.drop(columns = ["gender_","baseColour_","season_","usage_"])
test_lstm_df = pd.read_csv(data_dir + "test_lstm_X.csv")

train_lstm_df1 = pd.read_csv(data_dir + "new_train_lstm_X.csv")
test_lstm_df1 = pd.read_csv(data_dir + "new_test_lstm_X.csv")

category_xgb_train = pd.read_csv(data_dir + "category_xgb_train.csv")
category_xgb_train.columns = xgb_column_names
category_xgb_test = pd.read_csv(data_dir + "category_xgb_test.csv")
category_xgb_test.columns = xgb_column_names

# %%
train_total = pd.concat([category_xgb_train, train_fasttext_df, train_lstm_df1, train_image_df3],axis = 1)
test_total = pd.concat([category_xgb_test, test_fasttext_df, test_lstm_df1, test_image_df3],axis = 1)

xgb_train_X = train_total[:17000]
xgb_eval_X = train_total[17000:]

category_list = train["category"].unique()
category_list.sort()
category_mapping = {label:idx for idx,label in enumerate(category_list)}
num_mapping = {idx:label for idx,label in enumerate(category_list)}

train_total_Y = train['category'][:len(train)].map(category_mapping)

train_Y = train['category'][:17000].map(category_mapping)
eval_Y = train['category'][17000:len(train)].map(category_mapping)

xg_train = xgb.DMatrix(xgb_train_X, label=train_Y)
xg_eval = xgb.DMatrix(xgb_eval_X, label=eval_Y)  


# setup parameters for xgboost  
param = {}  
# use softmax multi-class classification  
param['objective'] = 'multi:softmax'  
# scale weight of positive examples  
param['eta'] = 0.1  
param['max_depth'] = 3  
# param['silent'] = 1  
param['nthread'] = 4  
param['num_class'] = 27  
  
watchlist = [(xg_train,'train'), (xg_eval, 'eval') ]  
num_round = 200  
# bst = xgb.train(param, xg_train, num_round, watchlist );

# get prediction  
# pred = bst.predict(xg_eval); 

# print ('predicting, classification error=%f' % (1- sum(eval_Y == pred)/len(pred)))

# %%
def xgb_train(X_train, Y_train, X_val, Y_val):
    xg_train = xgb.DMatrix(X_train, label=Y_train)
    xg_eval = xgb.DMatrix(X_val, label=Y_val)  


    watchlist = [(xg_train,'train'), (xg_eval, 'eval') ]  
    num_round = 200  
    bst = xgb.train(param, xg_train, num_round, watchlist );

    # get prediction  
    pred = bst.predict(xg_eval); 

    print ('predicting, classification error=%f' % (1- sum(Y_val == pred)/len(pred)))
    return bst,pred

# %%
xg_train = xgb.DMatrix(train_total, label=train_total_Y)
   
watchlist = [(xg_train,'train'), (xg_eval, 'eval') ]  
num_round = 150  
bst_FINAL = xgb.train(param, xg_train, num_round, watchlist );

# get prediction  
# pred_bst_FINAL = bst_FINAL.predict(xg_eval); 

# print ('predicting, classification error=%f' % (1- sum(eval_Y == pred)/len(pred)))
# Out:
# [0]	train-merror:0.026032	eval-merror:0.023557
# [1]	train-merror:0.023628	eval-merror:0.022477
# [2]	train-merror:0.022472	eval-merror:0.021396
# [3]	train-merror:0.021917	eval-merror:0.020316
# [4]	train-merror:0.021177	eval-merror:0.019235
# [5]	train-merror:0.020715	eval-merror:0.018803
# [6]	train-merror:0.020206	eval-merror:0.01837
# [7]	train-merror:0.01979	eval-merror:0.01837
# [8]	train-merror:0.019513	eval-merror:0.017938
# [9]	train-merror:0.019235	eval-merror:0.01837
# [10]	train-merror:0.018773	eval-merror:0.017506
# [11]	train-merror:0.018357	eval-merror:0.017074
# [12]	train-merror:0.018079	eval-merror:0.016209
# [13]	train-merror:0.017894	eval-merror:0.016209
# [14]	train-merror:0.017617	eval-merror:0.015345
# [15]	train-merror:0.017524	eval-merror:0.015561
# [16]	train-merror:0.017293	eval-merror:0.015345
# [17]	train-merror:0.016785	eval-merror:0.014912
# [18]	train-merror:0.016738	eval-merror:0.015129
# [19]	train-merror:0.016553	eval-merror:0.014912
# [20]	train-merror:0.016322	eval-merror:0.014912
# [21]	train-merror:0.016183	eval-merror:0.014696
# [22]	train-merror:0.015999	eval-merror:0.01448
# [23]	train-merror:0.016045	eval-merror:0.014696
# [24]	train-merror:0.015721	eval-merror:0.01448
# [25]	train-merror:0.015629	eval-merror:0.01448
# [26]	train-merror:0.01549	eval-merror:0.014264
# [27]	train-merror:0.015397	eval-merror:0.013832
# [28]	train-merror:0.01512	eval-merror:0.0134
# [29]	train-merror:0.014935	eval-merror:0.0134
# [30]	train-merror:0.014796	eval-merror:0.0134
# [31]	train-merror:0.014519	eval-merror:0.013183
# [32]	train-merror:0.014426	eval-merror:0.012751
# [33]	train-merror:0.014241	eval-merror:0.012535
# [34]	train-merror:0.014103	eval-merror:0.012535
# [35]	train-merror:0.013825	eval-merror:0.012319
# [36]	train-merror:0.013779	eval-merror:0.011887
# [37]	train-merror:0.013548	eval-merror:0.011238
# [38]	train-merror:0.01327	eval-merror:0.011022
# [39]	train-merror:0.013039	eval-merror:0.011022
# [40]	train-merror:0.012808	eval-merror:0.010806
# [41]	train-merror:0.012669	eval-merror:0.010806
# [42]	train-merror:0.012484	eval-merror:0.010806
# [43]	train-merror:0.012299	eval-merror:0.01059
# [44]	train-merror:0.012022	eval-merror:0.010374
# [45]	train-merror:0.011883	eval-merror:0.010374
# [46]	train-merror:0.011745	eval-merror:0.010158
# [47]	train-merror:0.01156	eval-merror:0.010158
# [48]	train-merror:0.011375	eval-merror:0.009942
# [49]	train-merror:0.011467	eval-merror:0.010158
# [50]	train-merror:0.011328	eval-merror:0.009942
# [51]	train-merror:0.011143	eval-merror:0.009942
# [52]	train-merror:0.01119	eval-merror:0.009942
# [53]	train-merror:0.011051	eval-merror:0.009509
# [54]	train-merror:0.010866	eval-merror:0.009293
# [55]	train-merror:0.010635	eval-merror:0.009293
# [56]	train-merror:0.010357	eval-merror:0.009077
# [57]	train-merror:0.010404	eval-merror:0.009293
# [58]	train-merror:0.010172	eval-merror:0.009293
# [59]	train-merror:0.009895	eval-merror:0.008645
# [60]	train-merror:0.009571	eval-merror:0.00778
# [61]	train-merror:0.00934	eval-merror:0.00778
# [62]	train-merror:0.009155	eval-merror:0.00778
# [63]	train-merror:0.008878	eval-merror:0.00778
# [64]	train-merror:0.008647	eval-merror:0.007348
# [65]	train-merror:0.008462	eval-merror:0.007132
# [66]	train-merror:0.008415	eval-merror:0.007132
# [67]	train-merror:0.008045	eval-merror:0.006916
# [68]	train-merror:0.007907	eval-merror:0.006916
# [69]	train-merror:0.007814	eval-merror:0.006916
# [70]	train-merror:0.007676	eval-merror:0.006916
# [71]	train-merror:0.007398	eval-merror:0.0067
# [72]	train-merror:0.007259	eval-merror:0.006484
# [73]	train-merror:0.007213	eval-merror:0.006484
# [74]	train-merror:0.007121	eval-merror:0.006268
# [75]	train-merror:0.006982	eval-merror:0.006268
# [76]	train-merror:0.006705	eval-merror:0.006051
# [77]	train-merror:0.006566	eval-merror:0.006051
# [78]	train-merror:0.006473	eval-merror:0.006051
# [79]	train-merror:0.006242	eval-merror:0.006051
# [80]	train-merror:0.005919	eval-merror:0.005835
# [81]	train-merror:0.00578	eval-merror:0.005835
# [82]	train-merror:0.005687	eval-merror:0.005403
# [83]	train-merror:0.005502	eval-merror:0.005187
# [84]	train-merror:0.005456	eval-merror:0.005187
# [85]	train-merror:0.005317	eval-merror:0.004971
# [86]	train-merror:0.004948	eval-merror:0.004971
# [87]	train-merror:0.004809	eval-merror:0.004971
# [88]	train-merror:0.004578	eval-merror:0.004755
# [89]	train-merror:0.004439	eval-merror:0.004971
# [90]	train-merror:0.004208	eval-merror:0.004539
# [91]	train-merror:0.004115	eval-merror:0.004539
# [92]	train-merror:0.003977	eval-merror:0.004539
# [93]	train-merror:0.003792	eval-merror:0.004539
# [94]	train-merror:0.003745	eval-merror:0.004539
# [95]	train-merror:0.003514	eval-merror:0.00389
# [96]	train-merror:0.003468	eval-merror:0.00389
# [97]	train-merror:0.00319	eval-merror:0.003458
# [98]	train-merror:0.002913	eval-merror:0.003242
# [99]	train-merror:0.002774	eval-merror:0.003242
# [100]	train-merror:0.002543	eval-merror:0.003242
# [101]	train-merror:0.002543	eval-merror:0.003242
# [102]	train-merror:0.002543	eval-merror:0.003242
# [103]	train-merror:0.002543	eval-merror:0.003242
# [104]	train-merror:0.002266	eval-merror:0.003242
# [105]	train-merror:0.002219	eval-merror:0.003242
# [106]	train-merror:0.002034	eval-merror:0.003026
# [107]	train-merror:0.001988	eval-merror:0.00281
# [108]	train-merror:0.00185	eval-merror:0.002377
# [109]	train-merror:0.001711	eval-merror:0.002377
# [110]	train-merror:0.001665	eval-merror:0.002377
# [111]	train-merror:0.001526	eval-merror:0.001945
# [112]	train-merror:0.00148	eval-merror:0.001945
# [113]	train-merror:0.00148	eval-merror:0.001945
# [114]	train-merror:0.001387	eval-merror:0.001729
# [115]	train-merror:0.001202	eval-merror:0.001513
# [116]	train-merror:0.001202	eval-merror:0.001513
# [117]	train-merror:0.001202	eval-merror:0.001513
# [118]	train-merror:0.001202	eval-merror:0.001513
# [119]	train-merror:0.001156	eval-merror:0.001297
# [120]	train-merror:0.001063	eval-merror:0.001297
# [121]	train-merror:0.000971	eval-merror:0.001297
# [122]	train-merror:0.000925	eval-merror:0.001081
# [123]	train-merror:0.000879	eval-merror:0.001081
# [124]	train-merror:0.000879	eval-merror:0.001081
# [125]	train-merror:0.000879	eval-merror:0.001081
# [126]	train-merror:0.000786	eval-merror:0.001081
# [127]	train-merror:0.000786	eval-merror:0.001081
# [128]	train-merror:0.000786	eval-merror:0.001081
# [129]	train-merror:0.00074	eval-merror:0.001081
# [130]	train-merror:0.000647	eval-merror:0.000864
# [131]	train-merror:0.000601	eval-merror:0.000864
# [132]	train-merror:0.000555	eval-merror:0.000864
# [133]	train-merror:0.000509	eval-merror:0.000864
# [134]	train-merror:0.000509	eval-merror:0.000864
# [135]	train-merror:0.000416	eval-merror:0.000864
# [136]	train-merror:0.000416	eval-merror:0.000864
# [137]	train-merror:0.00037	eval-merror:0.000864
# [138]	train-merror:0.000277	eval-merror:0.000648
# [139]	train-merror:0.000231	eval-merror:0.000432
# [140]	train-merror:0.000231	eval-merror:0.000432
# [141]	train-merror:0.000185	eval-merror:0.000216
# [142]	train-merror:0.000139	eval-merror:0.000216
# [143]	train-merror:0.000139	eval-merror:0.000216
# [144]	train-merror:0.000139	eval-merror:0.000216
# [145]	train-merror:0.000139	eval-merror:0.000216
# [146]	train-merror:0.000139	eval-merror:0.000216
# [147]	train-merror:0.000139	eval-merror:0.000216
# [148]	train-merror:0.000139	eval-merror:0.000216
# [149]	train-merror:0.000139	eval-merror:0.000216

# %%
xg_test = xgb.DMatrix(test_total) 
pred_xg_test = bst_FINAL.predict(xg_test)
test["class_num"] = pred_xg_test
test['category'] = test["class_num"].map(num_mapping)
submit_df = pd.DataFrame(test, columns = ['id','category'])

# %%
submit_df.to_csv("submit.csv",index=False)
